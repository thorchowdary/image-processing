# %%
from skimage import io

# %%
my_image=io.imread("t.jpg")

# %%
print(my_image.min(),my_image.max())
# Out:
# 0 255

# %%
from matplotlib import pyplot as plt
import numpy as np
from skimage import img_as_float

# %%
random_image=np.random.random([500,500])
my_float_image=img_as_float(random_image)
plt.imshow(random_image)
print(my_float_image)
print(my_float_image.min(),random_image.max())
# Out:
# [[0.87724021 0.64218087 0.26587222 ... 0.9808121  0.35993647 0.23166211]
#  [0.18999807 0.70992001 0.56800082 ... 0.82111224 0.78528187 0.78509016]
#  [0.12334898 0.30810387 0.2481553  ... 0.48724305 0.45047092 0.66911051]
#  ...
#  [0.08517027 0.02886507 0.63128195 ... 0.98398423 0.43356358 0.63732295]
#  [0.48124477 0.43159775 0.32312507 ... 0.33061621 0.51014176 0.40894241]
#  [0.72958645 0.48078262 0.1402891  ... 0.64651897 0.13894913 0.49588708]]
# 1.6422978998509308e-05 0.9999903199251784

# %%
dark_image=my_image*0.5
print(dark_image.max())
# Out:
# 127.5

# %%
my=np.random.random([234,455])
plt.imshow(my)

# %%
print(my)

# %%
my[10:200, 10:100 , :] = [255,  0, 0]
plt.imshow(my)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-422a3a86f2a2> in <module>
# ----> 1 my[10:200, 10:100 , :] = [255,  0, 0]
#       2 plt.imshow(my)
#
# IndexError: too many indices for array

# %%
from skimage import io

# %%
my_image=io.imread("t.jpg")

# %%
print(my_image)
# Out:
# [[[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]
#
#  [[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]
#
#  [[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]
#
#  ...
#
#  [[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]
#
#  [[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]
#
#  [[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]]

# %%
plt.imshow(my_image)

# %%
my_image[0:200,0:200, : ] = [200,200,3]

# %%
print(my_image)
plt.imshow(my_image)
# Out:
# [[[200 200   3]
#   [200 200   3]
#   [200 200   3]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]
#
#  [[200 200   3]
#   [200 200   3]
#   [200 200   3]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]
#
#  [[200 200   3]
#   [200 200   3]
#   [200 200   3]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]
#
#  ...
#
#  [[ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]
#
#  [[ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]
#
#  [[ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]]

# %%
from skimage import img_as_float

# %%
myimg_as_float=img_as_float(my_image)

# %%
print(myimg_as_float)
# Out:
# [[[0.78431373 0.78431373 0.01176471]
#   [0.78431373 0.78431373 0.01176471]
#   [0.78431373 0.78431373 0.01176471]
#   ...
#   [0.10980392 0.03921569 0.20392157]
#   [0.10980392 0.03921569 0.20392157]
#   [0.10980392 0.03921569 0.20392157]]
#
#  [[0.78431373 0.78431373 0.01176471]
#   [0.78431373 0.78431373 0.01176471]
#   [0.78431373 0.78431373 0.01176471]
#   ...
#   [0.10980392 0.03921569 0.20392157]
#   [0.10980392 0.03921569 0.20392157]
#   [0.10980392 0.03921569 0.20392157]]
#
#  [[0.78431373 0.78431373 0.01176471]
#   [0.78431373 0.78431373 0.01176471]
#   [0.78431373 0.78431373 0.01176471]
#   ...
#   [0.10980392 0.03921569 0.20392157]
#   [0.10980392 0.03921569 0.20392157]
#   [0.10980392 0.03921569 0.20392157]]
#
#  ...
#
#  [[0.10980392 0.03921569 0.20392157]
#   [0.10980392 0.03921569 0.20392157]
#   [0.10980392 0.03921569 0.20392157]
#   ...
#   [0.10980392 0.03921569 0.20392157]
#   [0.10980392 0.03921569 0.20392157]
#   [0.10980392 0.03921569 0.20392157]]
#
# ...

# %%
from skimage import io

# %%
from skimage import img_as_float

# %%
from matplotlib import pyplot as plt

# %%
 import numpy as np

# %%
my_image=np.random.random([500,500])

# %%
print(my_image)
# Out:
# [[0.53205811 0.58142361 0.20314615 ... 0.18804426 0.83361295 0.55147495]
#  [0.36411467 0.3963171  0.26832437 ... 0.69329002 0.78374227 0.68842092]
#  [0.41075351 0.04941409 0.68821417 ... 0.15488545 0.29646948 0.35445118]
#  ...
#  [0.55193795 0.98951083 0.55198854 ... 0.07152143 0.5561418  0.67345977]
#  [0.01960307 0.72819518 0.32453934 ... 0.34013893 0.71577498 0.9280112 ]
#  [0.05082052 0.14398418 0.42760603 ... 0.93358963 0.81126268 0.38291873]]

# %%
myimg_as_float=img_as_float(my_image)

# %%
print(myimg_as_float)
# Out:
# [[0.53205811 0.58142361 0.20314615 ... 0.18804426 0.83361295 0.55147495]
#  [0.36411467 0.3963171  0.26832437 ... 0.69329002 0.78374227 0.68842092]
#  [0.41075351 0.04941409 0.68821417 ... 0.15488545 0.29646948 0.35445118]
#  ...
#  [0.55193795 0.98951083 0.55198854 ... 0.07152143 0.5561418  0.67345977]
#  [0.01960307 0.72819518 0.32453934 ... 0.34013893 0.71577498 0.9280112 ]
#  [0.05082052 0.14398418 0.42760603 ... 0.93358963 0.81126268 0.38291873]]

# %%
dark_image=my_image*5

# %%
print(dark_image)
# Out:
# [[2.66029053 2.90711803 1.01573073 ... 0.94022131 4.16806477 2.75737475]
#  [1.82057337 1.98158551 1.34162184 ... 3.46645011 3.91871135 3.4421046 ]
#  [2.05376754 0.24707046 3.44107084 ... 0.77442724 1.48234739 1.77225591]
#  ...
#  [2.75968974 4.94755417 2.75994272 ... 0.35760717 2.78070901 3.36729887]
#  [0.09801535 3.64097589 1.62269668 ... 1.70069463 3.57887488 4.64005601]
#  [0.2541026  0.71992089 2.13803014 ... 4.66794817 4.05631341 1.91459363]]

# %%
my_img=io.imread("t.jpg")

# %%
print(my_img)
# Out:
# [[[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]
#
#  [[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]
#
#  [[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]
#
#  ...
#
#  [[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]
#
#  [[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]
#
#  [[28 10 52]
#   [28 10 52]
#   [28 10 52]
#   ...
#   [28 10 52]
#   [28 10 52]
#   [28 10 52]]]

# %%
plt.imshow(my_img)

# %%
my_img[0:200,0:200,:]=[225,0,0]

# %%
print(my_img)
plt.imshow(my_img)
# Out:
# [[[225   0   0]
#   [225   0   0]
#   [225   0   0]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]
#
#  [[225   0   0]
#   [225   0   0]
#   [225   0   0]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]
#
#  [[225   0   0]
#   [225   0   0]
#   [225   0   0]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]
#
#  ...
#
#  [[ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]
#
#  [[ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]
#
#  [[ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]
#   ...
#   [ 28  10  52]
#   [ 28  10  52]
#   [ 28  10  52]]]
